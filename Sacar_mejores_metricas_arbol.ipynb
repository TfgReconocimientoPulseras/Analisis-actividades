# %%
import numpy as np
import pandas as pd
from numpy import genfromtxt
from sklearn.tree import DecisionTreeClassifier

# %%
X_train= genfromtxt("X_train.csv", delimiter=',')
y_train= genfromtxt("y_train.csv", delimiter='')
X_train[np.isnan(X_train)] = np.median(X_train[~np.isnan(X_train)])
X_val= genfromtxt("X_val.csv", delimiter=',')
y_val= genfromtxt("y_val.csv", delimiter='')
X_val[np.isnan(X_val)] = np.median(X_val[~np.isnan(X_val)])

# %%
min_samples_split = [0.001, 0.01, 0.025, 0.1, 0.2, 0.5, 50, 25, 10]
split_len = len(min_samples_split)
min_samples_leaf = [0.001, 0.01, 0.025, 0.1, 0.2, 0.5, 50, 25, 10]
leaf_len = len(min_samples_leaf)

precision = 0
split = 0
leaf = 0
max_por = 0

for i in range(split_len):
    for j in range(leaf_len):
        clf = DecisionTreeClassifier(criterion='entropy',random_state=0, min_samples_split = min_samples_split[i], min_samples_leaf = min_samples_leaf[j])
        clf = clf.fit(X_train, y_train)
        precision = clf.score(X_val ,y_val)*100
        print("- Precisión(Accuracy) del modelo: {0: .9}".format(precision))
        print("  min_samples_split: {}, min_samples_leaf: {}".format(min_samples_split[i], min_samples_leaf[j]))
        if precision > max_por:
            max_por = precision
            split = min_samples_split[i]
            leaf = min_samples_leaf[j]

print("\n\nMáxima precisión(Accuracy): {},\nmin_samples_split: {}, min_samples_leaf: {}".format(max_por, split, leaf))
# Out:
# - Precisión(Accuracy) del modelo:  38.7732749
#   min_samples_split: 0.001, min_samples_leaf: 0.001
# - Precisión(Accuracy) del modelo:  31.5443593
#   min_samples_split: 0.001, min_samples_leaf: 0.01
# - Precisión(Accuracy) del modelo:  27.9299014
#   min_samples_split: 0.001, min_samples_leaf: 0.025
# - Precisión(Accuracy) del modelo:  40.6352683
#   min_samples_split: 0.001, min_samples_leaf: 0.1
# - Precisión(Accuracy) del modelo:  36.0350493
#   min_samples_split: 0.001, min_samples_leaf: 0.2
# - Precisión(Accuracy) del modelo:  20.0438116
#   min_samples_split: 0.001, min_samples_leaf: 0.5
# - Precisión(Accuracy) del modelo:  26.5060241
#   min_samples_split: 0.001, min_samples_leaf: 50
# - Precisión(Accuracy) del modelo:  31.4348302
#   min_samples_split: 0.001, min_samples_leaf: 25
# - Precisión(Accuracy) del modelo:  26.6155531
#   min_samples_split: 0.001, min_samples_leaf: 10
# - Precisión(Accuracy) del modelo:  35.3778751
#   min_samples_split: 0.01, min_samples_leaf: 0.001
# - Precisión(Accuracy) del modelo:  31.5443593
#   min_samples_split: 0.01, min_samples_leaf: 0.01
# - Precisión(Accuracy) del modelo:  27.9299014
#   min_samples_split: 0.01, min_samples_leaf: 0.025
# - Precisión(Accuracy) del modelo:  40.6352683
#   min_samples_split: 0.01, min_samples_leaf: 0.1
# - Precisión(Accuracy) del modelo:  36.0350493
#   min_samples_split: 0.01, min_samples_leaf: 0.2
# - Precisión(Accuracy) del modelo:  20.0438116
#   min_samples_split: 0.01, min_samples_leaf: 0.5
# - Precisión(Accuracy) del modelo:  26.5060241
#   min_samples_split: 0.01, min_samples_leaf: 50
# - Precisión(Accuracy) del modelo:  31.4348302
#   min_samples_split: 0.01, min_samples_leaf: 25
# - Precisión(Accuracy) del modelo:  36.1445783
#   min_samples_split: 0.01, min_samples_leaf: 10
# - Precisión(Accuracy) del modelo:  28.3680175
#   min_samples_split: 0.025, min_samples_leaf: 0.001
# - Precisión(Accuracy) del modelo:  31.6538883
#   min_samples_split: 0.025, min_samples_leaf: 0.01
# - Precisión(Accuracy) del modelo:  27.9299014
#   min_samples_split: 0.025, min_samples_leaf: 0.025
# - Precisión(Accuracy) del modelo:  40.6352683
#   min_samples_split: 0.025, min_samples_leaf: 0.1
# - Precisión(Accuracy) del modelo:  36.0350493
#   min_samples_split: 0.025, min_samples_leaf: 0.2
# - Precisión(Accuracy) del modelo:  20.0438116
#   min_samples_split: 0.025, min_samples_leaf: 0.5
# - Precisión(Accuracy) del modelo:  26.5060241
#   min_samples_split: 0.025, min_samples_leaf: 50
# - Precisión(Accuracy) del modelo:  31.2157722
#   min_samples_split: 0.025, min_samples_leaf: 25
# - Precisión(Accuracy) del modelo:  25.1916758
#   min_samples_split: 0.025, min_samples_leaf: 10
# - Precisión(Accuracy) del modelo:  27.8203724
#   min_samples_split: 0.1, min_samples_leaf: 0.001
# - Precisión(Accuracy) del modelo:  28.9156627
#   min_samples_split: 0.1, min_samples_leaf: 0.01
# - Precisión(Accuracy) del modelo:  26.8346112
#   min_samples_split: 0.1, min_samples_leaf: 0.025
# - Precisión(Accuracy) del modelo:  40.6352683
#   min_samples_split: 0.1, min_samples_leaf: 0.1
# - Precisión(Accuracy) del modelo:  36.0350493
#   min_samples_split: 0.1, min_samples_leaf: 0.2
# - Precisión(Accuracy) del modelo:  20.0438116
#   min_samples_split: 0.1, min_samples_leaf: 0.5
# - Precisión(Accuracy) del modelo:  28.9156627
#   min_samples_split: 0.1, min_samples_leaf: 50
# - Precisión(Accuracy) del modelo:  28.9156627
#   min_samples_split: 0.1, min_samples_leaf: 25
# - Precisión(Accuracy) del modelo:  28.9156627
#   min_samples_split: 0.1, min_samples_leaf: 10
# - Precisión(Accuracy) del modelo:  29.6823658
#   min_samples_split: 0.2, min_samples_leaf: 0.001
# - Precisión(Accuracy) del modelo:  29.6823658
#   min_samples_split: 0.2, min_samples_leaf: 0.01
# - Precisión(Accuracy) del modelo:  28.3680175
#   min_samples_split: 0.2, min_samples_leaf: 0.025
# - Precisión(Accuracy) del modelo:  40.6352683
#   min_samples_split: 0.2, min_samples_leaf: 0.1
# - Precisión(Accuracy) del modelo:  36.0350493
#   min_samples_split: 0.2, min_samples_leaf: 0.2
# - Precisión(Accuracy) del modelo:  20.0438116
#   min_samples_split: 0.2, min_samples_leaf: 0.5
# - Precisión(Accuracy) del modelo:  29.6823658
#   min_samples_split: 0.2, min_samples_leaf: 50
# - Precisión(Accuracy) del modelo:  29.6823658
#   min_samples_split: 0.2, min_samples_leaf: 25
# - Precisión(Accuracy) del modelo:  29.6823658
#   min_samples_split: 0.2, min_samples_leaf: 10
# - Precisión(Accuracy) del modelo:  38.992333
#   min_samples_split: 0.5, min_samples_leaf: 0.001
# - Precisión(Accuracy) del modelo:  38.992333
#   min_samples_split: 0.5, min_samples_leaf: 0.01
# - Precisión(Accuracy) del modelo:  38.992333
#   min_samples_split: 0.5, min_samples_leaf: 0.025
# - Precisión(Accuracy) del modelo:  38.992333
#   min_samples_split: 0.5, min_samples_leaf: 0.1
# - Precisión(Accuracy) del modelo:  38.992333
#   min_samples_split: 0.5, min_samples_leaf: 0.2
# - Precisión(Accuracy) del modelo:  20.0438116
#   min_samples_split: 0.5, min_samples_leaf: 0.5
# - Precisión(Accuracy) del modelo:  38.992333
#   min_samples_split: 0.5, min_samples_leaf: 50
# - Precisión(Accuracy) del modelo:  38.992333
#   min_samples_split: 0.5, min_samples_leaf: 25
# - Precisión(Accuracy) del modelo:  38.992333
#   min_samples_split: 0.5, min_samples_leaf: 10
# - Precisión(Accuracy) del modelo:  35.3778751
#   min_samples_split: 50, min_samples_leaf: 0.001
# - Precisión(Accuracy) del modelo:  31.5443593
#   min_samples_split: 50, min_samples_leaf: 0.01
# - Precisión(Accuracy) del modelo:  27.9299014
#   min_samples_split: 50, min_samples_leaf: 0.025
# - Precisión(Accuracy) del modelo:  40.6352683
#   min_samples_split: 50, min_samples_leaf: 0.1
# - Precisión(Accuracy) del modelo:  36.0350493
#   min_samples_split: 50, min_samples_leaf: 0.2
# - Precisión(Accuracy) del modelo:  20.0438116
#   min_samples_split: 50, min_samples_leaf: 0.5
# - Precisión(Accuracy) del modelo:  26.5060241
#   min_samples_split: 50, min_samples_leaf: 50
# - Precisión(Accuracy) del modelo:  31.4348302
#   min_samples_split: 50, min_samples_leaf: 25
# - Precisión(Accuracy) del modelo:  26.6155531
#   min_samples_split: 50, min_samples_leaf: 10
# - Precisión(Accuracy) del modelo:  38.3351588
#   min_samples_split: 25, min_samples_leaf: 0.001
# - Precisión(Accuracy) del modelo:  31.5443593
#   min_samples_split: 25, min_samples_leaf: 0.01
# - Precisión(Accuracy) del modelo:  27.9299014
#   min_samples_split: 25, min_samples_leaf: 0.025
# - Precisión(Accuracy) del modelo:  40.6352683
#   min_samples_split: 25, min_samples_leaf: 0.1
# - Precisión(Accuracy) del modelo:  36.0350493
#   min_samples_split: 25, min_samples_leaf: 0.2
# - Precisión(Accuracy) del modelo:  20.0438116
#   min_samples_split: 25, min_samples_leaf: 0.5
# - Precisión(Accuracy) del modelo:  26.5060241
#   min_samples_split: 25, min_samples_leaf: 50
# - Precisión(Accuracy) del modelo:  31.4348302
#   min_samples_split: 25, min_samples_leaf: 25
# - Precisión(Accuracy) del modelo:  26.6155531
#   min_samples_split: 25, min_samples_leaf: 10
# - Precisión(Accuracy) del modelo:  43.8116101
#   min_samples_split: 10, min_samples_leaf: 0.001
# - Precisión(Accuracy) del modelo:  31.5443593
#   min_samples_split: 10, min_samples_leaf: 0.01
# - Precisión(Accuracy) del modelo:  27.9299014
#   min_samples_split: 10, min_samples_leaf: 0.025
# - Precisión(Accuracy) del modelo:  40.6352683
#   min_samples_split: 10, min_samples_leaf: 0.1
# - Precisión(Accuracy) del modelo:  36.0350493
#   min_samples_split: 10, min_samples_leaf: 0.2
# - Precisión(Accuracy) del modelo:  20.0438116
#   min_samples_split: 10, min_samples_leaf: 0.5
# - Precisión(Accuracy) del modelo:  26.5060241
#   min_samples_split: 10, min_samples_leaf: 50
# - Precisión(Accuracy) del modelo:  31.4348302
#   min_samples_split: 10, min_samples_leaf: 25
# - Precisión(Accuracy) del modelo:  26.6155531
#   min_samples_split: 10, min_samples_leaf: 10
#
#
# Máxima precisión(Accuracy): 43.8116100767,
# min_samples_split: 10, min_samples_leaf: 0.001
